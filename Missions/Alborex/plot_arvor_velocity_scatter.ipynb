# %%
import os
import numpy as np
import netCDF4
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import rcParams
# %matplotlib inline

# %%
rcParams.update({'font.size': 22})

# %%
arvorfile = ('http://thredds.priv.socib.es/thredds/dodsC/drifter/profiler_drifter/'
             'profiler_drifter_arvora3001-ogs_arvora3001/L1/2014/'
             'dep0001_profiler-drifter-arvora3001_ogs-arvora3001_L1_2014-05-25.nc')

# %%
with netCDF4.Dataset(arvorfile) as nc:
    lon = nc.variables['LON'][:]
    lat = nc.variables['LAT'][:]
    temp = nc.variables['WTR_TEM'][:, 0]

# %%
temp.shape
# Out:
# (12,)

# %%
plt.scatter(lon, lat, c=temp, s=15, edgecolor='None', vmin=18.5, vmax=19.5)
plt.colorbar()
plt.show()

# %%
temp
# Out:
# masked_array(data = [19.099 19.091 19.049 19.015 19.004 18.994 18.987 18.983 18.975 18.914
#  18.829 18.554],
#              mask = [False False False False False False False False False False False False],
#        fill_value = nan)
